# %% [markdown]
# ## HomeworkQuestions:
#
# ### Part I    Current Status Evaluation
# 1. For each category (Office Supplies, Contingent Labor, Legal Services), create a bar chart
# with respect to the total spend by each supplier. What do you observe?
# 2. For each category (Office Supplies, Contingent Labor, Legal Services), create a strategic
# matrix plot using geographic coverage against total spend and populate data of the suppliers.
# What do you find from each plot?
# 3. Other than geographic coverage, what are the other metrics you would take into
# consideration in terms of supplier rationalization? Calculate the weighted average score for
# criticality and quality. For each of these metrics, create a strategic matrix plots against total
# spend by populating the data. What can you tell from the plots? Create a strategic matrix
# plot populating criticality against quality for each category. What insights do the plots
# provide?
#
# ### Part II    Strategy Recommendation and Justification
# 4. How do different characteristics of the three categories (Office Supplies, Contingent Labor,
# and Legal Services) influence your viewpoint on supplier rationalization? Compare the
# categories and discuss the differences.
# 5. What is the number of suppliers you recommend for each category (1, 2 to 10, or more than
# 10)? Justify your answer by computing the savings opportunity and/or evaluating the key
# metrics you use and the pros and cons of your recommendation.

# %% [markdown]
# ## notes:
#
# Talat built a new global indirect procurement team of 21 global and regional sourcing
# specialists (Exhibit 1). Within the team, the U.S. segment was further subdivided and specialized
# to perform more detailed analyses on multiple categories of spend.
#
# In 2019, Koe-Meyer spent $1 billion on the indirect procurement including HR, IT, Professional
# Services, Travel, Operations and Marketing. This expenditure was segmented by the company’s
# business regions (Exhibit 2). The total annual spend in the U.S. accounted for 85% in the
# Americas, which was about $493 million (Exhibit 3). There were over 10,000 suppliers—a
# monumental task—on Talat’s table to rationalize. Even though there was a focus on suppliers
# with strategic relationships, there existed a long tail of suppliers with relatively small scale and
# local presence. The CPO and her team decided to kick off a strategic sourcing initiative to reduce
# the number of suppliers and deliver savings to Koe-Meyer. They created a strategic matrix based
# on the company’s spend by supplier and the supplier’s geographic coverage of business. They
# also prioritized the initial focus on three categories, Office Supplies, Contingent Labor, and
# Legal Services, including 248 suppliers and accounting for $71 million of total third-party spend.
# Each of these 248 suppliers was segmented by category and related spend, and scored based on
# its geographic coverage from local to nationwide on a scale of 1 to 10 (Exhibit 4.1, 4.2, 4.3).
#                                                                                                                                           4
# After plotting out the strategic matrix and populating supplier data, the suppliers could be further
# subdivided into (i) strategic partnerships—suppliers who should be properly maintained and
# strengthened, (ii) local—suppliers who might play an important part locally, (iii) value-added—
# suppliers who had a potential to grow further, and (iv) cut-the-tail—suppliers who might be
# terminated and whose spend might be redistributed (Exhibit 5).
#
# The team also performed analyses on the criticality and the quality of each supplier. Criticality
# stands for the level of business impact each supplier had on the company, consisting of Available
# Capacity, Switching Costs, Substitution Options, Savings Opportunity, and Integrated Solution.
# Quality measures the degree of performance excellence and unique attributes possessed by each
# supplier, including Leadership, Innovation, Technology, Compliance, and Customer Services
# (Exhibit 6). Each attribute for criticality and quality was scored from 1 to 10 and assigned
# percentage weight of importance in Exhibit 7.1, 7.2, 7.3 and Exhibit 8.1, 8.2, 8.3.
#
# These questions forced them to think through the comparison between single source strategy and multiple supplier strategy.
#
# Single source strategy, relying on one supplier for all of the demand in the category, brings the
# benefits of procurement synergy. Bulk purchasing and volume bundling create economies of
# scale, increasing the company’s buying power, gaining deeper discounts and attaining lower unit
# costs. It also unifies the administrative processes and streamlines the procedures, making it easier
# to maintain or strengthen the supplier relationship. However, the dependency can introduce high
# risk in the case of sudden shortage or other emergencies with the supplier.
# On the other hand, multiple supplier strategy mitigates this kind of risk by allocating
# procurement focus onto multiple suppliers. Some suppliers, albeit small and local, provide
# critical products or services and cannot be replaced by other suppliers. This strategy makes
# demand fluctuations and supply disruptions more manageable. Additionally, while there is
# relatively low buying power to be leveraged, there may be some chance to take advantage of the
# competition among the suppliers. Yet, it requires more overhead and management time and can
# reduce the overall responsiveness and information sharing.
#
# Talat listed out three sourcing strategy options for each indirect procurement category: (i)
# centralizing all demand to one single supplier, (ii) relying on a small group of suppliers ranging from 2 to 10,
# and (iii) sourcing from a large group of suppliers greater than 10. To select the right
# sourcing strategy for each category, the team had to plot the position of each supplier onto the
# strategic matrix, understand the importance of each supplier based on its criticality and quality,
# and identify the possible supplier candidates to choose and compare. Their decision-making also
# had to be backed up by the possible financial impact. In the end, the CPO would have to decide
# the optimal strategy for each category and report to the C-Suite and other executives.
#
# ![alt text](image.png)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#read in data
file_path = '/home/jovyan/456/456supplychainanalytics/Koe-Meyer Case/Koe-Meyer Data.xlsx'

alldf = pd.read_excel(file_path, sheet_name='All')
officedf = pd.read_excel(file_path, sheet_name='Office Supplies')
contlabordf = pd.read_excel(file_path, sheet_name='Contingent Labor')
legalservicesdf = pd.read_excel(file_path, sheet_name='Legal Services')

# %% [markdown]
# For each category (Office Supplies, Contingent Labor, Legal Services), create a bar chart
# with respect to the total spend by each supplier. What do you observe?

# %%
# Creating the bar chart
plt.figure(figsize=(10, 6))
plt.bar(officedf['Supplier'], officedf['Total Spend'], color='blue')

# Adding title and labels
plt.title('Total Spend by Each Supplier')
plt.xlabel(officedf['Supplier'])
plt.ylabel(officedf['Total Spend'])

# Showing the plot
plt.show()

# %% [markdown]
# # Part 2

# %% [markdown]
# # Part 3

# %% [markdown]
# Calculating Weighted Average scores .
#
# As given in the exhibits , we have the following data.
#
# Criticality Metrics and Weights:
#
# -
# Available Capacity (20%
# - )-
# Switching Costs (25%)
# Substitution Options (15%)
# Savings Opportunity (30%)
# Integrated Solution (10%)
# Quality Metrics and Weights:
# Leadership (10%)
# Innovation (35%)
# Technology (20%)
# Compliance (10%)
# Customer Service (25%)

# %%
# Define weights for criticality and quality metrics
criticality_weights = {
    'Available Capacity': 0.20,
    'Switching Costs': 0.25,
    'Substitution Options': 0.15,
    'Savings Opportunity': 0.30,
    'Integrated Solutions': 0.10
}

quality_weights = {
    'Leadership': 0.10,
    'Innovation': 0.35,
    'Technology': 0.20,
    'Compilance': 0.10,
    'Customer Services': 0.25
}

# Function to calculate weighted average score
def calculate_weighted_average(df, weights):
    return sum(df[column] * weight for column, weight in weights.items())

# Calculate weighted average scores for Office Supplies
officedf['Criticality Score'] = officedf.apply(lambda row: calculate_weighted_average(row, criticality_weights), axis=1)
officedf['Quality Score'] = officedf.apply(lambda row: calculate_weighted_average(row, quality_weights), axis=1)

# Calculate weighted average scores for Contingent Labor
contlabordf['Criticality Score'] = contlabordf.apply(lambda row: calculate_weighted_average(row, criticality_weights), axis=1)
contlabordf['Quality Score'] = contlabordf.apply(lambda row: calculate_weighted_average(row, quality_weights), axis=1)

# Calculate weighted average scores for Legal Services
legalservicesdf['Criticality Score'] = legalservicesdf.apply(lambda row: calculate_weighted_average(row, criticality_weights), axis=1)
legalservicesdf['Quality Score'] = legalservicesdf.apply(lambda row: calculate_weighted_average(row, quality_weights), axis=1)

# Display the updated dataframes with new scores
print(officedf[['Supplier', 'Criticality Score', 'Quality Score']].head())
print(contlabordf[['Supplier', 'Criticality Score', 'Quality Score']].head())
print(legalservicesdf[['Supplier', 'Criticality Score', 'Quality Score']].head())
# Out:
#                  Supplier  Criticality Score  Quality Score
# 0              OFFICE INC               4.25           5.65
# 1        STAPLES & SCHOKS               8.20           8.95
# 2                INDO-OFF               3.70           5.50
# 3  TWIST & SHINE PRODUCTS               6.05           3.60
# 4  GUERNSEY BEST PRODUCTS               3.85           3.30
#                  Supplier  Criticality Score  Quality Score
# 0                MBI CREW               7.15           6.15
# 1                 EK DATA               7.95           5.80
# 2  INCREDIBLE OUTSOURCING               7.20           7.00
# 3          INFO RESOURCES               7.50           7.20
# 4                    MODE               8.45           6.50
#            Supplier  Criticality Score  Quality Score
# 0            AXIONG               3.25           7.05
# 1           RESMITH               8.45           8.40
# 2  ARNES & HORNBURG               7.65           7.95
# ...

# %%
# Function to create strategic matrix plots
def plot_strategic_matrix(df, x_col, y_col, title, x_label, y_label):
    plt.figure(figsize=(10, 6))
    plt.scatter(df[x_col], df[y_col], c='blue', marker='o')
    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.grid(True)
    plt.show()

# %%
# Plot for Office Supplies
plot_strategic_matrix(officedf, 'Total Spend', 'Criticality Score', 'Office Supplies: Total Spend vs Criticality Score', 'Total Spend', 'Criticality Score')

# %% [markdown]
# ### Insights
#
# The mean score of 5.41 suggests that the average supplier is moderately critical to Koe-Meyer’s operations.
# The scores are relatively spread out, as indicated by the standard deviation of 1.32
#
# High Criticality Suppliers: Suppliers with scores closer to the maximum of 8.20 should be prioritized for strategic partnerships and careful contract management due to their high importance.
# Low Criticality Suppliers: Suppliers with scores near the minimum of 2.80 may be candidates for rationalization or replacement if cost-saving measures are needed, as they are less critical to operations..

# %%
plot_strategic_matrix(officedf, 'Criticality Score', 'Quality Score', 'Office Supplies: Criticality vs Quality Score', 'Criticality Score', 'Quality Score')

# %%
# Plot for Contingent Labor
plot_strategic_matrix(contlabordf, 'Total Spend', 'Criticality Score', 'Contingent Labor: Total Spend vs Criticality Score', 'Total Spend', 'Criticality Score')

# %% [markdown]
# ### Insights from the Total Spend vs Criticality Score (Contingent Labor) Analysis
#
# - Mean: $877,193
# - Standard Deviation: $2,792,136
# - Minimum: $257
# - 25th Percentile (Q1): $7,216
# - Median (Q2): $60,966
# - 75th Percentile (Q3): $217,226
# - Maximum: $18,425,169
#
# ### Descriptive Statistics for Criticality Score:
# - Mean: 5.80
# - Standard Deviation: 1.33
# - Minimum: 3.10
# - 25th Percentile (Q1): 4.75
# - Median (Q2): 5.80
# - 75th Percentile (Q3): 6.95
#
# - High Spend and High Criticality: Suppliers of this category are both high spend and high criticality, making them crucial to operations and potential targets for strategic partnerships and contract negotiations.
# -
# Low Spend and High Criticality: Suppliers such as KFORC and MEDI have high criticality scores but low spend, indicating their essential role despite a smaller financial footprint. These suppliers should be maintained for their critical contributions.icality Score: 0.31

# %%
plot_strategic_matrix(contlabordf, 'Total Spend', 'Quality Score', 'Contingent Labor: Total Spend vs Quality Score', 'Total Spend', 'Quality Score')

# %% [markdown]
# Weak Positive Correlation: The weak positive correlation (0.22) between Total Spend and Quality Score suggests that while there is some relationship, higher spend does not strongly correlate with higher quality. Each supplier's quality should be independently evaluated along with their spend to ensure a balanced and effective supplier strategy.
#
# Focus on High-Quality Suppliers: Prioritize suppliers with high quality scores for long-term contracts and strategic partnerships to ensure consistent service quality.

# %%
plot_strategic_matrix(contlabordf, 'Criticality Score', 'Quality Score', 'Contingent Labor: Criticality vs Quality Score', 'Criticality Score', 'Quality Score')

# %% [markdown]
# High Criticality and High Quality: Suppliers of this category are both highly critical and high quality. These suppliers are crucial and provide high-quality services, making them strategic partners worth maintaining and possibly expanding business .
#
# High Criticality but Moderate Quality: Suppliers such as EK DATA and KFORC have high criticality scores but moderate quality scores. These suppliers are essential for operations but might require quality improvement initiatives to ensure they meet high service standards.

# %%
plot_strategic_matrix(legalservicesdf, 'Total Spend', 'Criticality Score', 'Legal Services: Total Spend vs Criticality Score', 'Total Spend', 'Criticality Score')

# %%
plot_strategic_matrix(legalservicesdf, 'Total Spend', 'Quality Score', 'Legal Services: Total Spend vs Quality Score', 'Total Spend', 'Quality Score')

# %% [markdown]
#  The very weak positive correlation (0.11) between Total Spend and Criticality Score suggests that there is almost no relationship between the amount spent on suppliers and their criticality. This indicates that each supplier’s value should be evaluated independently of their spend .
#
#  Rationalize Low-Value Suppliers: Consider phasing out suppliers with both low spend and low criticality to streamline the supplier base and reduce management overhead.

# %%
plot_strategic_matrix(legalservicesdf, 'Criticality Score', 'Quality Score', 'Legal Services: Criticality vs Quality Score', 'Criticality Score', 'Quality Score')

# %% [markdown]
# # 1.  Strategic matrix plots ( Criticality vs quality )

# %%
# Define a function to add quadrants to the plot
def add_quadrants(ax):
    xlim = ax.get_xlim()
    ylim = ax.get_ylim()
    ax.axhline(y=(ylim[0] + ylim[1]) / 2, color='black', linestyle='--')
    ax.axvline(x=(xlim[0] + xlim[1]) / 2, color='black', linestyle='--')
    ax.text(xlim[0] + (xlim[1] - xlim[0]) / 4, ylim[1] - (ylim[1] - ylim[0]) / 10, 'High Quality, Low Criticality', fontsize=12, ha='center')
    ax.text(xlim[0] + 3 * (xlim[1] - xlim[0]) / 4, ylim[1] - (ylim[1] - ylim[0]) / 10, 'High Quality, High Criticality', fontsize=12, ha='center')
    ax.text(xlim[0] + (xlim[1] - xlim[0]) / 4, ylim[0] + (ylim[1] - ylim[0]) / 10, 'Low Quality, Low Criticality', fontsize=12, ha='center')
    ax.text(xlim[0] + 3 * (xlim[1] - xlim[0]) / 4, ylim[0] + (ylim[1] - ylim[0]) / 10, 'Low Quality, High Criticality', fontsize=12, ha='center')

# Function to create strategic matrix plot
def plot_strategic_matrix_with_quadrants(df, x_col, y_col, title, x_label, y_label):
    fig, ax = plt.subplots(figsize=(10, 6))
    scatter = ax.scatter(df[x_col], df[y_col], s=100, c='blue', alpha=0.6, edgecolors='w', linewidth=0.5)
    
    # Annotate each point with the supplier name
    for i, row in df.iterrows():
        ax.annotate(row['Supplier'], (row[x_col], row[y_col]), fontsize=9)
    
    ax.set_title(title)
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    ax.grid(True)
    
    # Add quadrants to the plot
    add_quadrants(ax)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Office category

# %%
# Assuming you have already calculated the Criticality Score and Quality Score for Office Supplies
plot_strategic_matrix_with_quadrants(officedf, 'Criticality Score', 'Quality Score', 'Office Supplies: Criticality vs Quality Score', 'Criticality Score', 'Quality Score')

# %% [markdown]
# # Contingent labor

# %%
# Create the plot for Contingent Labor
plot_strategic_matrix_with_quadrants(contlabordf, 'Criticality Score', 'Quality Score', 'Contingent Labor: Criticality vs Quality Score', 'Criticality Score', 'Quality Score')

# %% [markdown]
# # Legal services

# %%
# Create the plot for Legal Services
plot_strategic_matrix_with_quadrants(legalservicesdf, 'Criticality Score', 'Quality Score', 'Legal Services: Criticality vs Quality Score', 'Criticality Score', 'Quality Score')

# %% [markdown]
# # Strategic matrix plot ( Spend vs Criticality score )

# %%
# Plot Total Spend vs Criticality Score for Contingent Labor
plot_strategic_matrix_with_quadrants(officedf, 'Total Spend', 'Criticality Score', 'Office Supplies: Total Spend vs Criticality Score', 'Total Spend', 'Criticality Score')

# %%
# Plot Total Spend vs Quality Score for Contingent Labor
plot_strategic_matrix_with_quadrants(contlabordf, 'Total Spend', 'Quality Score', 'Contingent Labor: Total Spend vs Quality Score', 'Total Spend', 'Quality Score')

# %%
# Plot Total Spend vs Criticality Score for Legal Services
plot_strategic_matrix_with_quadrants(legalservicesdf, 'Total Spend', 'Criticality Score', 'Legal Services: Total Spend vs Criticality Score', 'Total Spend', 'Criticality Score')
